# %% [markdown]
# <a href="https://colab.research.google.com/github/LinearRecession/TelecomPlanRecommender/blob/main/TelecomPlans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --no-cache-dir transformers sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 123.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 303.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 276.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 226.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 205.4 MB/s eta 0:00:00
# ...

# %%
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.6/107.6 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torch-scatter: filename=torch_scatter-2.1.1-cp310-cp310-linux_x86_64.whl size=489401 sha256=455e39ce02aeb247b6df1c08c3aba4fb2c08c979dfde6327d4253b36a02f6e38
#   Stored in directory: /root/.cache/pip/wheels/ef/67/58/6566a3b61c6ec0f2ca0c2c324cd035ef2955601f0fb3197d5f
# Successfully built torch-scatter
# ...

# %%
import torch
torch.__version__
# Out:
# '2.0.1+cu118'

# %%
from transformers import pipeline
from transformers import AutoTokenizer
import pandas as pd

# %%
tokenizer = AutoTokenizer.from_pretrained("google/tapas-base-finetuned-wtq", use_fast=False)

# %%
tqa = pipeline(task="table-question-answering",model="google/tapas-base-finetuned-wtq")

# %%
table=pd.read_json("PlansTable.json")

# %% [markdown]
# # New Section

# %%
table = table.astype(str)

# %%
table
# Out:
#                                               plan  \
# 0                                    UltraNet Plan
# 1                                InfiniteSurf Plan
# 2                                  MegaStream Plan
# 3                                   FamilyMax Plan
# 4                               FamilyConnect Plan
# 5                               GlobalConnect Plan
# 6                                   WorldTalk Plan
# 7                                    VoiceMax Plan
# 8                                   VoicePlus Plan
# 9                                 StudentSurf Plan
# 10                             StudentConnect Plan
# 11                                    DataMax Plan
# 12                               SuperConnect Plan
# 13                                 All-in-One Plan
# 14                                 SeniorSurf Plan
# 15                              SeniorConnect Plan
# 16                                PrepaidSurf Plan
# ...

# %%
query = "I want a plan with 5G"
print(tqa(table=table,query=query)["answer"])
# Out:
# 5GMax Plan
